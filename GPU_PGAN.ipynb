# %%
# Imports
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt 
# from scipy.interpolate import interp1d, interp2d 
# import scipy.io as sio 
from scipy.signal import max_len_seq 
# from imageio import imread
import torch
# print(torch.__file__)
# print(torch.version.cuda)
# print(torch.cuda.is_available())
# # import torchvision
import torchvision.transforms as transforms
import PIL.Image as Image
# # from skimage.transform import resize
import matplotlib.colors as pltc
import math
# import pickle

# %%
def greyscale(x):
    r, g, b = x[0,:,:], x[1,:,:], x[2,:,:]
    return 0.299 * r + 0.587 * g + 0.114 * b

# %%
def psnr(img1, img2):
    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    mse = np.mean((img1 - img2)**2)
    if mse == 0:
        return float('inf')
    return 20 * math.log10(255.0 / math.sqrt(mse))

# %%
def color_range(tens):
  out = tens.detach().numpy()
  out = out/np.amax(out)
  out = np.clip(out, 0, 1); # Converting to correct color range
  return out

# %%
numScenePix = 256;  # Changing 256 to 64
numMaskPix = 63; unitMask = 30; 
numSensorPix = 512; unitSensor = 8;
d = 4000;

midScenePix = int(np.floor(numScenePix/2)) 
midSensorPix = int(np.floor(numSensorPix/2))-1  

z2a = lambda z: (1-d/z) 
a2z = lambda a: d/(1-a) 
crop_sensor = lambda x: x[midScenePix: midScenePix+numSensorPix, midScenePix:midScenePix+numSensorPix]
crop_img = lambda x: x[midSensorPix: midSensorPix+numScenePix, midSensorPix: midSensorPix+numScenePix]

depthList = z2a(np.array([50e4])) # 50cm away

# define functions for interpolation
locSensor = np.linspace(-numSensorPix*unitSensor/2 + unitSensor/2, numSensorPix*unitSensor/2 - unitSensor/2, numSensorPix) 
locMask = np.linspace(-numMaskPix*unitMask/2 + unitMask/2, numMaskPix*unitMask/2 - unitMask/2, numMaskPix) 

# Function needed for Generating PSF
def generateInterpMatrix(depthList, locSensor, locMask):
    numDepth = depthList.size
    interpMatrix = np.zeros([numSensorPix, numMaskPix, numDepth])
    for di in np.arange(numDepth):
        locInterp = depthList[di]*locSensor
        hi = np.minimum(len(locMask) - 1, np.searchsorted(locMask, locInterp, 'right'))
        lo = np.maximum(0, hi - 1)
        interpMatrix[np.arange(len(lo)), lo, di] = 1 - (locInterp - locMask[lo])/unitMask
        interpMatrix[np.arange(len(hi)), hi, di] = 1 - (locMask[hi] - locInterp)/unitMask
        rowsCast = np.where(np.logical_or(locInterp<locMask[0], locInterp>locMask[-1] ))
        interpMatrix[rowsCast, :, di] = 0
    return interpMatrix

# %%
# create mask pattern
maskVec = max_len_seq(int(np.log2(numMaskPix+1)))[0].reshape(numMaskPix,1)
maskPattern = maskVec @ maskVec.T 

# generate interpolation matrices for multiple depths
interpMatrix = generateInterpMatrix(depthList, locSensor, locMask)[:,:,0]
psf = interpMatrix @ maskPattern @ interpMatrix.T # The Point Spread Function

plt.figure(1)
plt.subplot(121); plt.imshow(maskPattern); plt.title('mask pattern'); plt.axis('off');
plt.subplot(122); plt.imshow(psf); plt.title('psf'); plt.axis('off');

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# read image
im = Image.open('Images/Jpeg/InNature.jpg').convert('L')  # Original Image
im = np.array(im)
print(im.shape)

# forward model 
fullLength = numSensorPix + numScenePix - 1
psf_fft = np.fft.fft2(psf, s=[fullLength,fullLength])
img_fft = np.fft.fft2(im, s=[fullLength,fullLength])
y_fft = psf_fft * img_fft # Ax
y = crop_sensor(np.fft.ifft2(y_fft).real) # sensor measurements 

# add gaussian noise
std = 0.2
y = y + np.random.normal(loc=0, scale=std, size=(numSensorPix,numSensorPix)) # + mu
# im = im - 1
plt.figure(1)
plt.subplot(231);plt.imshow(psf); plt.title('psf'); plt.axis('off');
plt.subplot(232);plt.imshow(im, cmap='gray'); plt.title('image'); plt.axis('off'); # Displaying original image
plt.subplot(233);plt.imshow(y); plt.title('sensor measurements'); plt.axis('off');
plt.subplot(234);plt.imshow(np.log(np.fft.fftshift(np.abs(psf_fft)))); plt.title('psf fft'); plt.axis('off'); # What is the fft? Feed-Forward...?
plt.subplot(235);plt.imshow(np.log(np.fft.fftshift(np.abs(img_fft)))); plt.title('img fft'); plt.axis('off'); # Fourier Transform -> Convolution
plt.subplot(236);plt.imshow(np.log(np.fft.fftshift(np.abs(y_fft)))); plt.title('measurements fft'); plt.axis('off');

# %%
# inverse 
# Original Weiner Filter Implementation
# snr = signal to noise ratio. Represented as 'K' in the original formula
lambda_snr = np.sqrt(std) # regularization parameter for noise reduction ---- > Fine tune this
xhat_fft = (np.conjugate(psf_fft) * np.fft.fft2(y,s=[fullLength,fullLength] )) / (np.abs(psf_fft)**2 + lambda_snr )
xhat = crop_img(np.fft.fftshift(np.fft.ifft2(xhat_fft).real)) 

plt.figure(2)
plt.subplot(121);plt.imshow(im, cmap='gray');plt.title('original image'); plt.axis('off');
plt.subplot(122);plt.imshow(xhat, cmap='gray');plt.title('reconstructed image');plt.axis('off');

# %% [markdown]
# # Gradient Descent
#
# - Each Iteration is: $x_k = x_{k-1} - A^T(Ax_{k-1} - y)$, where k is the number of iterations

# %%
# crop_fft = lambda x: x[0:numScenePix, 0:numScenePix]
# A = lambda x: np.fft.ifft2(psf_fft * np.fft.fft2(x, s=np.array([fullLength,fullLength]),norm='ortho')).real
# AT = lambda y: crop_fft(np.fft.ifft2(np.conjugate(psf_fft) * np.fft.fft2(y,norm='ortho'))).real # Doesn't return an image

# %%
# yn = A(im)
# plt.subplot(121); plt.imshow(yn); plt.title('yn'); plt.axis('off')
# plt.subplot(122); plt.imshow(A(im)); plt.title('A(im)'); plt.axis('off') # Sensor Measurements.

# %%
# # Loss Function
# def loss(z): # Z is the reconstructed image
#   _in = A(z) - yn
#   _in = torch.from_numpy(_in)
#   return torch.linalg.norm(_in)**2 # ||AG(z) - y||2^2

# print(loss(im))

# %%
# Reconstruction Error
# def recon_err(z):
#   _in = z - im
#   _in = torch.from_numpy(_in)
#   return torch.linalg.norm(_in)**2 

# print(recon_err(xhat))

# %%
# Gradient
# def grad(z, yn):
#   return AT(A(z) - yn) # A^T(A(z) - y)
  # return torch.from_numpy(AT(A(G(z)) - yn))

# %%
# Our goal was to make bad reconstructions better, 
# So let's make up a "bad reconstruction", and try and make it better
# init = np.random.normal(loc=0, scale=0.35, size=(256,256))
# init = np.random.rand(256,256)
# init = np.random.rand(64,64)
# plt.imshow(init); plt.axis('off');

# %%
# Example of how the Inital Image 'improves' each iteration (here is showing just 1)
# test_z = init - (0.01 * grad(init, yn))
# plt.imshow(test_z); plt.axis('off');

# %%
# def gd(sensor_measurements, learning_rate=0.01, max_iterations=100, tol=2000): # Starting with a simple 5 iterations
#   it = 1; relative_cost = float('inf'); 
#   loss_hist = np.zeros(max_iterations) # 
#   z_hist = np.zeros((max_iterations, im.shape[0], im.shape[1])) # Contains all previous reconstructions
#   # print(z_hist.shape)
#   # print(max_iterations)
#   z_hist[0][:][:] = init
#   loss_hist[0] = loss(z_hist[0])

#   while (it < max_iterations or relative_cost < tol):
#     # print(it)
#     z_k_1 = z_hist[it-1][:][:]
#     z_k = z_k_1 - (learning_rate * grad(z_k_1, sensor_measurements)) # x_k = x_{k-1} - grad(x_{k-1})
#     z_hist[it][:][:] = z_k
#     curr_loss = loss(z_hist[it]) # L
#     loss_hist[it] = curr_loss
#     relative_cost = recon_err(z_k) # compared to Tolerance
#     it += 1
#   return loss_hist, z_hist

# %%
# l_h, z_h = gd(yn)

# %%
# print(loss(z_h[0]))
# plt.plot(l_h)

# %%
# for i in range(0,100,5):
#   plt.imshow(z_h[i]) 
#   plt.pause(0.1)

# %%
# plt.imshow(z_h[99] - z_h[0]); plt.colorbar();
# print(z_h[0].min())
# print(z_h[0].max())

# %%
# print(l_h)

# %%
# plt.subplot(121); plt.imshow(z_h[0]); plt.axis('off');
# plt.subplot(122); plt.imshow(z_h[99]); plt.axis('off');
# print(loss(A(z_h[99])))

# %%
# img = z_h[99]
# plt.imsave('out.jpg', img)

# %% [markdown]
# # Load in a Training Dataset

# %%
# Load in a Pretrained Model
import torch.hub
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ### Re-write Functions to use Torch instead of Numpy

# %%
# Possibly need to change these values ... 
crop_fft = lambda x: x[0:numScenePix, 0:numScenePix]
psf_fft = torch.tensor(psf_fft)
A = lambda x: torch.fft.ifft2(psf_fft * torch.fft.fft2(x, s=([fullLength,fullLength]), norm='ortho')).real
AT = lambda y: crop_fft(torch.fft.ifft2(torch.conj(psf_fft) * torch.fft.fft2(y, norm='ortho'))).real

# %% [markdown]
# ##### Writing A(x) for RGB Images

# %%
def A(x): 
    if len(x.size()) == 3:
        out = torch.zeros(767,767,3); # print("Shape is 3D")
        for i in range(0,3): # Input is shape [H,W,3]
            curr_channel = x[:,:,i]
            out[:,:,i] = torch.fft.ifft2(psf_fft * torch.fft.fft2(curr_channel, s=([fullLength,fullLength]), norm='ortho')).real
    else: 
        out = torch.fft.ifft2(psf_fft * torch.fft.fft2(x, s=([fullLength,fullLength]), norm='ortho')).real 
    return out

# %%
# img = Image.open('Images/Jpeg/InNature.jpg')  # Test Image
# img = np.array(img)
# img = torch.from_numpy(img)
# print(img.shape);
# # plt.imshow(img[:,:,0]); plt.axis('off'); 

# fig1, ax = plt.subplots(1,2,figsize=(10,5))
# one_dim = A(torch.from_numpy(im))
# three_dim = A(img)
# three_dim_disp = three_dim.numpy(); three_dim_disp = three_dim_disp/np.amax(three_dim_disp); three_dim_disp = np.clip(three_dim_disp, 0, 1); # Converting to correct color 
# ax[0].imshow(one_dim); ax[0].set_title('Grey A(x)');
# ax[1].imshow(three_dim_disp); ax[1].set_title('RGB A(x)');

# %%
# crop = lambda x: x[383:639, 383:639]
# xhat_fft = (np.conjugate(psf_fft) * np.fft.fft2(one_dim,s=[fullLength,fullLength] )) / (np.abs(psf_fft)**2 + lambda_snr )
# xhat = crop(np.fft.fftshift(np.fft.ifft2(xhat_fft).real))
# plt.subplot(121); plt.imshow(xhat, cmap='gray'); plt.title('Gray A(x)'); plt.axis('off'); 

# # --------------------------------------------------------
# # RGB Version
# xhat_fft_rgb = torch.zeros(767,767,3);
# xhat_rgb = torch.zeros(256,256,3);
# for i in range(0,3):
#     xhat_fft_rgb[:,:,i] = (torch.conj(psf_fft) * torch.fft.fft2(three_dim[:,:,i],s=[fullLength,fullLength] )) / (torch.abs(psf_fft)**2)
#     xhat_rgb[:,:,i] = crop(torch.fft.fftshift(torch.fft.ifft2(xhat_fft_rgb[:,:,i]).real))

# xhat_rgb = color_range(xhat_rgb) # Color Correction 
# plt.subplot(122); plt.imshow(xhat_rgb); plt.title('RGB A(x)'); plt.axis('off');

# %% [markdown]
# ## Defining DCGAN

# %% [markdown]
# ### Load DCGAN

# %% [markdown]
# Option 1: DCGAN trained on FashionGen \\
# Option 2: Progressive GAN trained on celebAHQ-256

# %%
use_gpu = True if torch.cuda.is_available() else False
print(use_gpu)
# model = torch.hub.load('facebookresearch/pytorch_GAN_zoo:hub', 'DCGAN', pretrained=True, useGPU=use_gpu)
model = torch.hub.load('facebookresearch/pytorch_GAN_zoo:hub','PGAN', model_name='celebAHQ-256', pretrained=True, useGPU=use_gpu)

# %% [markdown]
# Option 3: StyleGan2 trained on FFHQ
#   - Requires `ffhq.pkl`

# %%
# torch.enable_grad()

# with open('D:/UCR/Research/Zips/ffhq.pkl', 'rb') as f:
#     netG = pickle.load(f)['G_ema']

# torch.set_grad_enabled(True)
# # Force Values to Floating Point in order to preserve CPU usage
# import functools
# netG.forward = functools.partial(netG.forward, force_fp32=True)
# torch.set_default_tensor_type('torch.cuda.FloatTensor')
# print(netG)

# %%
# nc = 1 # Number of channels in the training images. For color images this is 3
nz = 512 # nz = 120 # Size of z latent vector (i.e. size of generator input)
# ngf = 64 # Size of feature maps in generator
# ndf = 64 # Size of feature maps in discriminator

# Number of GPUs available. Use 0 for CPU mode.
ngpu = 1
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
print(device)

# %%
# When we want to reclaim memory
# !pip install GPUtil
import gc
import GPUtil
gc.collect()
torch.cuda.empty_cache() # And then empty it

# %% [markdown]
# ### Define Generator(z)
# - We define the Generator function when we already have pre-trained weights

# %%
# Define Generator for Self-Trained DCGAN
# class Generator(nn.Module):
#     def __init__(self, ngpu):
#         super(Generator, self).__init__()
#         self.ngpu = ngpu
#         self.main = nn.Sequential(
#             # input is Z, going into a convolution
#             nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
#             nn.BatchNorm2d(ngf * 8),
#             nn.ReLU(True),
#             # state size. (ngf*8) x 4 x 4
#             nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf * 4),
#             nn.ReLU(True),
#             # state size. (ngf*4) x 8 x 8
#             nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf * 2),
#             nn.ReLU(True),
#             # state size. (ngf*2) x 16 x 16
#             nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf),
#             nn.ReLU(True),
#             # state size. (ngf) x 32 x 32
#             nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
#             nn.Tanh()
#             # state size. (nc) x 64 x 64
#         )


#     def forward(self, input):
#         return self.main(input)

# %%
# Define Generator for CIFAR-100 DCGAN
# class Generator(nn.Module):
#     def __init__(self, ngpu, nc=1, nz=100, ngf=64):
#         super(Generator, self).__init__()
#         self.ngpu = ngpu
#         self.main = nn.Sequential(
#             # input is Z, going into a convolution
#             nn.ConvTranspose2d(     nz, ngf * 8, 4, 1, 0, bias=False),
#             nn.BatchNorm2d(ngf * 8),
#             nn.ReLU(True),
#             # state size. (ngf*8) x 4 x 4
#             nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf * 4),
#             nn.ReLU(True),
#             # state size. (ngf*4) x 8 x 8
#             nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf * 2),
#             nn.ReLU(True),
#             # state size. (ngf*2) x 16 x 16
#             nn.ConvTranspose2d(ngf * 2,     ngf, 4, 2, 1, bias=False),
#             nn.BatchNorm2d(ngf),
#             nn.ReLU(True),
#             nn.ConvTranspose2d(    ngf,      nc, kernel_size=1, stride=1, padding=0, bias=False),
#             nn.Tanh()
#         )

#     def forward(self, input):
#         if input.is_cuda and self.ngpu > 1:
#             output = nn.parallel.data_parallel(self.main, input, range(self.ngpu))
#         else:
#             output = self.main(input)
#         return output

# %%
# netG = Generator(ngpu).to(device)
# # netG.load_state_dict(torch.load('D:/UCR/Research/DCGAN/generator.pth')) # CelebA Self-Trained
# # netG.load_state_dict(torch.load('D:/UCR/Research/lineCam/netG_epoch_299.pth', map_location=torch.device('cpu'))) # CIFAR-Pretrained
# netG.eval()

# %% [markdown]
# ### Define G(z)

# %%
 # Size of the Model 
GPUtil.showUtilization()

# %%
def G(z): # Input to the Model is a [N,nz,1,1], s.t. nz = latent vector
    out = model.netG(z) # out = netG(z)
    # out = F.interpolate(out, scale_factor=1/4, recompute_scale_factor=True) # Rescaling
    # print(out.dtype)
    # print(out.shape)  
    return out # Output [1,3,64,64]

# ---------------------------------------------------------
# Testing out the G(z) Function
# with torch.no_grad():
#   # i = G(torch.randn([1,nz]).cuda())[0] # ([3, 256, 256])
#   i = G(torch.randn([1,nz]))[0] # ([3, 256, 256])
#   print(i.shape) # Confirm correct shape
#   id = color_range(i.cpu())
#   plt.figure(figsize=(7,7))
#   plt.imshow(id.transpose(1,2,0)); plt.axis('off');
# del i
# GPUtil.showUtilization()

# %%
# Want to confirm torch.no_grad() blocks VRAM consumption
# tests = torch.zeros(100,3,256,256)
# with torch.no_grad():
#   for i in range(0,100):
#     tests[i,:,:,:] = G(torch.randn([1,nz]))[0]
# GPUtil.showUtilization()

# %% [markdown]
# ### Sub-Sampling

# %% [markdown]
# #### Archived Sampling Methods

# %%
# def Slices(dim1, dim2, slc, col=False):
#       w_sigma = torch.zeros((3,dim1,dim2))
#   for i in range(0,3):
#     w_sigma[i,0:dim1:slc] = 1
#   if col == True:
#         w_sigma = torch.transpose(w_sigma, 1, 2)
#   return w_sigma

# def even_prct_chunks(dim1, dim2, percentage=0.1, num_chunks=2, col=False):
#   w_sigma = torch.zeros((3,dim1, dim2))
#   num_rows = int(w_sigma.shape[1] * percentage) # 153
#   if(num_rows < num_chunks) or (num_chunks <= 1): 
#     print("Error, Percentage or num_chunks is too Low!")

#   id = dim1 / num_chunks # <---- 
#   chk_sz = num_rows / num_chunks
#   for i in range(0, num_chunks):
#     for j in range(0,3):
#       start = int(id*i)
#       end = int(start + chk_sz)
#       # if j==0:
#       #   print(start,end)
#       w_sigma[j][start:end] = 1
#   if col == True:
#         w_sigma = torch.transpose(w_sigma, 1, 2)
#   return w_sigma

# Random Distribution - Chooses a % of Random Rows 
# def rand_dst(dim1, dim2, percentage, col=False):
#   w_sigma = torch.zeros((3,dim1,dim2))
#   num_rows = int(w_sigma.shape[1] * percentage)

#   for i in range(0, num_rows):
#     idx = rand_roll(w_sigma.shape[1] - 1)
#     if w_sigma[:,idx].sum() == 0:
#       for j in range(0,3):
#         w_sigma[j,idx] = 1
#   if col == True:
#         w_sigma = torch.transpose(w_sigma, 1, 2)
#   return w_sigma

# %% [markdown]
# #### Random Sampling Methods

# %%
import random

# Random Roll - Helper Function to give value between 0 and x 
def rand_roll(x):
    return random.randint(0,x)

# Roll Between - Helper Function to give value between a start and end
def roll_btwn(strt, end):
    return random.randint(strt,end)
  
# Random Pixels - Chooses a % of Random Pixels
def rand_pxl(dim1, dim2, prct, HER=False):
      w_sigma = torch.zeros((dim1,dim2,3))
      num_pixels = int((dim1 * dim2) * prct);
      
      if HER == True:
            for i in range(0,num_pixels):
                  x = roll_btwn(120, 632) # placing a specific 512
                  y = roll_btwn(120, 632)
                  for j in range(0,3):
                        w_sigma[x,y,j] = 1          
      else:
            for i in range(0,num_pixels):
                  x = rand_roll(dim1 - 1)
                  y = rand_roll(dim2 - 1)
                  for j in range(0,3):
                        w_sigma[x,y,j] = 1
      return w_sigma


test2 = rand_pxl(767,767, 0.25, True);

plt.figure(figsize=(15,15))
plt.subplot(121); plt.imshow(test2.cpu()); plt.axis('off'); plt.title('Random Pixels');

# %% [markdown]
# ### Define Parameter Z
#
# - The low-dimensional space vector will follow the format required from the DCGAN

# %%
# z = torch.nn.Parameter(torch.randn(1,nz).cuda()) # Randomly initialize a value for 'z'

# %% [markdown]
# ### Create a New Test Image

# %%
# Testing Random Image Generation --------------------- 
with torch.no_grad():
  test_image = G(torch.randn(1,nz).cuda())[0] # ([3,256,256])
ti = color_range(test_image.cpu())
plt.subplot(121); plt.imshow(ti.transpose(1,2,0)); plt.axis('off'); plt.title("Test (Gen'd) Image");

# Testing A(x) -------------------------
test = A(test_image.cpu().permute(1,2,0))
test_sm = color_range(test.cpu())
plt.subplot(122); plt.imshow(test_sm); plt.axis('off'); plt.title('Sensor Measurements')

# Init yn
yn = test.detach(); # (767,767,3)
GPUtil.showUtilization()

# %%
# plt.imsave('TestImage.png', ti.transpose(1,2,0))
original_im = test_image.cpu().permute(1,2,0)

# %% [markdown]
# ### OR Load it from Memory

# %%
celeb = Image.open('D:/UCR/Research/TestImage.png').convert('RGB')   # Test Image from CelebAHQ-256 Dataset
plt.imshow(celeb); plt.axis('off');
transform = transforms.ToTensor()
test_image = transform(celeb); print(test_image.shape); # ([3,256,256])

# %%
# Load the saved tensor
with torch.no_grad():
    plt.figure(figsize=(9,9))
    original_im = test_image.cpu().permute(1,2,0)
    li = color_range(test_image.cpu()) # (3,256,256) # li = original loaded image, color corrected
    # plt.subplot(121); plt.imshow(li.transpose(1,2,0)); plt.axis('off'); plt.title("Loaded Test (Gen'd) Image");
    plt.subplot(121); plt.imshow(test_image.cpu().permute(1,2,0)); plt.axis('off'); plt.title("Loaded Test (Gen'd) Image");

    # Testing A(x) ---------------------
    load_sm = A(test_image.cpu().permute(1,2,0))
    disp_sm = color_range(load_sm.cpu())
    plt.subplot(122); plt.imshow(disp_sm); plt.axis('off'); plt.title('Loaded Sensor Measurements')

    # Init yn
    yn = load_sm.detach(); # [767,767,3]
    GPUtil.showUtilization();

# %%
plt.imsave('SM.png', disp_sm)

# %%
# Lets see if we can sub sample the Sensor Measurements of the Diffuser
# w_sigma = torch.ones((767,767,3))
w_sigma = rand_pxl(767,767,0.25,True)

# print(w_sigma.shape) # Confirm correct shape
plt.subplot(121); plt.imshow(w_sigma[:,:,0].cpu(), cmap='Accent'); plt.axis('off'); plt.title('sampling matrix');

# Create sensor_measurements_sparse
# print(yn.shape, w_sigma.shape)
y_sparse = w_sigma * yn;
y_s_d = color_range(y_sparse.cpu())
plt.subplot(122); plt.imshow(y_s_d); plt.axis('off'); plt.title('y_sparse');
GPUtil.showUtilization()

# %%
plt.imsave('SpareSM.png', y_s_d)
plt.imsave('Sampling.png', w_sigma[:,:,0].cpu(), cmap='Accent')

# %%
# -- Loss Function --
def loss_net(z):
  val = G(z)[0]; # Produces an Image, Shape (3,H=64,W=64)
  # plt.subplot(121); plt.imshow(val.cpu().detach().permute(1,2,0)) # Showing val (Generated Image)
  # plt.subplot(122); plt.imshow(A(val.cpu().detach().permute(1,2,0))) # Showing A(val) (Calculated Sensor Measurements for the Image)
  # return torch.linalg.norm(A(val.permute(1,2,0)) - yn)**2 # ||AG(z) - y||2^2
  return torch.linalg.norm((w_sigma * A(val.cpu().permute(1,2,0))) - y_sparse)**2 # ||AG(z) - y||2^2

# -- Reconstruction Error --
def recon_err_net(z):
    u = G(z)[0] # z will be the actual latent vector 'z'
    # plt.imshow(u.cpu().detach().permute(1,2,0)) # Showing val (Generated Image)
    # print(test_image.shape)
    return torch.mean((u.cpu().permute(1,2,0) - original_im)**2) # ||G(z_hat) - x*||2^2

# -- Random Initialization --
# -- Initalize a better 'z' by minimizing loss --
# def rand_init():
#       num_samples = 10
#       sample_list = torch.zeros(num_samples,1,nz) # List of randomly initialized samples
#       loss_list = torch.zeros(num_samples) # List of loss values

#       for it in range(0,10):
#         if(it % 5 == 0):
#           GPUtil.showUtilization()
#           print(it)
#         sample = torch.randn(1,nz) # Generate a random sample
#         curr_loss = loss_net(sample) # Calculate loss w/ sample
#         sample_list[it] = sample  # Add sample to list
#         loss_list[it] = curr_loss # Min loss corresponds to values at this index
          
#       min_loss = torch.min(loss_list)
#       min_loss_idx = torch.argmin(loss_list)
#       print(min_loss, "Index " + str(min_loss_idx))
#       new_z = sample_list[min_loss_idx]  
#       return new_z
    
with torch.no_grad():
  # -- Testing Loss Function (using no grad)
  Loss_test = loss_net(torch.randn(1,nz).cuda())
  print(Loss_test)

  # -- Testing Reconstruction Error Function (using no grad)
  re_test = recon_err_net(torch.randn(1,nz).cuda())
  print(re_test)

z = torch.nn.Parameter(torch.randn(1,nz).cuda(), requires_grad=True) # Randomly initialize a  # Randomly initialize a value for 'z'

# %% [markdown]
# # Define an Optimizer

# %%
import torch.optim as optim
import cv2
import os
# optimizer = optim.SGD([z], lr=0.001) # Stochastic Gradient Descent 
optimizer = optim.Adam([z], lr=0.1) # Adam Optimizer
# optimizer = optim.RMSprop([z], lr=0.00001) # RMSprop Optimizer # Lower sampling rate
lmda = lambda x: 0.1
scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lmda)
total_iterations = 2000 # Use 10000 ?
max_iters = 500

# %%
def recon_init(z):
    r_hist = torch.zeros(total_iterations)
    images = torch.zeros(3,256,256,total_iterations)
    tol = True
    it = 0; epoch = 1;

    for epoch in range(1,5):
        print("Starting Epoch %d" % epoch);
        while(it < (epoch * max_iters) and tol == True):
            if(it % 100 == 0):
                print("Iteration: %d" % it)
            # GPUtil.showUtilization()
            optimizer.zero_grad()
            
            R = recon_err_net(z) # z - sensor measurements
            torch.autograd.backward(R, retain_graph=False, create_graph=False) 
            optimizer.step()
            
            with torch.no_grad(): 
                gen_img = G(z) 
                images[:,:,:,it] = gen_img
                r_hist[it] = R
            # if(r_hist[it] < 1000):
            #     tol = False
            #     print("Iteration: %d" % it)
            #     r_hist[it:] = R   
            it += 1
            del R, gen_img
    
    epoch += 1
    scheduler.step()
    print('Done!')
    
    return z, r_hist, images

# %%
def loss_init(z):
  loss_history = torch.zeros(max_iterations)
  rec_history = torch.zeros(max_iterations)
  img_list = torch.zeros(3,256,256,max_iterations)
  tol = True
  it = 0

  while (it < max_iterations and tol == True):
    if(it % 100 == 0):
      print("Iteration: %d" % it)
      # GPUtil.showUtilization()
   
    L = loss_net(z) # z - sensor measurements
    torch.autograd.backward(L, retain_graph=False, create_graph=False) 
    optimizer.step()
    optimizer.zero_grad()
    with torch.no_grad():
      gen_img = G(z) 
      img_list[:,:,:,it] = gen_img
      R = recon_err_net(z) # Reconstruction Error
    rec_history[it] = R
    loss_history[it] = L
    if(loss_history[it] < 1000):
          tol = False
          print("Iteration: %d" % it)
          loss_history[it:] = L # Fix Loss and Rec Graphs
          rec_history[it:] = R
    it += 1
    del L, R, gen_img

  print('Done!')

  return z, loss_history, rec_history, img_list 

# Currently 12:05 Execution Time via COLAB
# Currently 3:53/7:33 Execution Time via LOCAL MCHN

# %%
opt_z, r_hist, images = recon_init(z)
# epochs = 2;
# Optimized_Z = torch.zeros(epochs,1,nz)

# for e in range(0,int(epochs)):
#     Optimized_Z[e], = recon_init(z)

# min_z = torch.min(Optimized_Z,0)
# min_z_idx = torch.argmin(Optimized_Z, 0)
# Opt_z = Optimized_Z[min_z_idx]
# r_hist = R_History[min_z_idx]
# images = Image_List[min_z_idx,:,:,:,:]

#       print(min_loss, "Index " + str(min_loss_idx))
#       new_z = sample_list[min_loss_idx]  
#       return new_z

# %%
plt.semilogy(r_hist[0:].detach().numpy()); plt.title("Reconstruction Error History")

# %%
for i in range(0,2000):
    img = images[:,:,:,i]
    disp_img = color_range(img); display = color_range(img);
    disp_img = 255 * (disp_img - disp_img.min()) / (disp_img.max() - disp_img.min()); disp_img = np.array(disp_img, np.float32);
    cv2.imwrite('Images/GIF_Images/image' + "0" + str(i) + '.png', cv2.cvtColor(disp_img.transpose(1,2,0), cv2.COLOR_RGB2BGR))
    # plt.imshow(display.transpose(1,2,0)); plt.axis('off'); plt.title('Iteration '+ str(i))
    # plt.pause(0.1)

# %%
optimizer = optim.RMSprop([opt_z], lr=0.001) # RMSprop Optimizer # Lower sampling rate
max_iterations = 2000 # Use 10000 ?
final_z, loss_history, rec_history, img_list = loss_init(opt_z)

# %%
# print(loss_history[0:].detach().numpy())
plt.figure(figsize=(15,5))
plt.subplot(121); plt.semilogy(loss_history[0:].detach().numpy()); plt.title("Loss History")
plt.subplot(122); plt.plot(rec_history[0:].detach().numpy()); plt.title("Reconstruction Error History")
print(loss_history[-1]) # Get last loss
# plt.savefig('D:/UCR/Research/Images/figs/history' + str(10) + '%' + 'test5' + '.png')

# %% [markdown]
# #### Observing Change from 0-100
#
# - The first ~200 iterations have the greatest change, so let's examine those for now.

# %%
# Save the first 200 images, because they show the greatest change.

# for i in range(0,200,5):
#     img = img_list[:,:,:,i]
#     disp_img = color_range(img); display = color_range(img);
#     disp_img = 255 * (disp_img - disp_img.min()) / (disp_img.max() - disp_img.min()); disp_img = np.array(disp_img, np.float32);
    # cv2.imwrite('Images/GIF_Images/image' + str(i) + '.png', cv2.cvtColor(disp_img.transpose(1,2,0), cv2.COLOR_RGB2BGR))
    # plt.imshow(img_list[:,:,:,i].detach().numpy().transpose(1,2,0)); plt.axis('off'); plt.title('Iteration '+ str(i))
    # plt.pause(0.1)

# Can save the img_list using first_100 = np.zeros(3,256,256,100); first_100[:,:,;,j] = img_list[:,:,:,i]; np.save(first_100.detach().numpy());

# %%
# Then save more intermediate images, since the change is not as great

for i in range(0,2000,100):
    img = img_list[:,:,:,i]
    disp_img = color_range(img); display = color_range(img);
    # disp_img = 255 * (disp_img - disp_img.min()) / (disp_img.max() - disp_img.min()); disp_img = np.array(disp_img, np.float32);
    # cv2.imwrite('D:/UCR/Research/Images/GIF_Images/image' + str(i) + '.png', cv2.cvtColor(disp_img.transpose(1,2,0), cv2.COLOR_RGB2BGR))
    plt.imshow(display.transpose(1,2,0)); plt.axis('off'); plt.title('Iteration '+ str(i))
    plt.pause(0.1)

# %%
# Display Images

# for i in range(0,2000,200):
#     plt.imshow(img_list[:,:,:,i].detach().numpy().transpose(1,2,0)); plt.axis('off'); plt.title('Iteration '+ str(i))
#     plt.pause(0.1)

# %%
recon = G(z)[0] # Optimized Reconstructed Image (Tensor, uses Grad)
recon_norm = color_range(recon.cpu()) # Reconstruction converted to Color Range
# start = img_list[:,:,:,0]; start = color_range(start); # First Iteration
start = images[:,:,:,0]; start = color_range(start); # First Iteration
# Calculate PSNR -- Using 2 Floats in this Calculation
# R = 'max int value of depth'
# ti = li # 
# print(ti.shape, recon_norm.shape)
nl = cv2.PSNR(recon_norm, ti, R=1) # Noise Level 
nl2 = psnr(recon_norm, ti)
print(nl, nl2)

plt.figure(figsize=(15,15))
plt.subplot(131); plt.imshow(ti.transpose(1,2,0)); plt.axis('off'); plt.title('Original')
plt.subplot(132); plt.imshow(recon_norm.transpose(1,2,0)); plt.axis('off'); plt.title('Optimized PSNR: %f' % nl);
plt.subplot(133); plt.imshow(start.transpose(1,2,0)); plt.axis('off'); plt.title('Iteration '+ str(0));

# plt.savefig('D:/UCR/Research/Images/figs/fig' + str(10) + '%' + 'test5' + '.png')
# plt.savefig('D:/UCR/Research/Images/figs/fig' + str(25) + '_col' + '.png')

# print(recon.max(), recon.min())

# %%
plt.imsave('OptImg.png', recon_norm.transpose(1,2,0))
plt.imsave('It0.png', start.transpose(1,2,0))

# %%
# diff = recon_norm.transpose(1,2,0) - ti.transpose(1,2,0)
# plt.imshow(diff)
recon_A_gt = A(recon.cpu().detach().permute(1,2,0))
recon_A = color_range(recon_A_gt)
# print(recon_A.shape)
# print(disp_sm.shape)
plt.figure(figsize=(15,15))
plt.subplot(131); plt.imshow(disp_sm); plt.axis('off'); plt.title('Original SM');
plt.subplot(132); plt.imshow(recon_A); plt.axis('off'); plt.title('Optimized SM');
plt.subplot(133); plt.imshow(disp_sm - recon_A); plt.axis('off'); plt.title('Diff');

# %%
# Original Image
image_fft_rgb = torch.zeros(767,767,3);
image_rgb = torch.zeros(256,256,3);
for i in range(0,3):
    image_fft_rgb[:,:,i] = (torch.conj(psf_fft) * torch.fft.fft2(yn[:,:,i],s=[fullLength,fullLength] )) / (torch.abs(psf_fft)**2)
    image_rgb[:,:,i] = crop(torch.fft.fftshift(torch.fft.ifft2(image_fft_rgb[:,:,i]).real))

image_rgb = color_range(image_rgb) # Color Correction 
plt.subplot(121); plt.imshow(image_rgb); plt.title('Original'); plt.axis('off'); 

# Optimized
recon_fft_rgb = torch.zeros(767,767,3);
recon_rgb = torch.zeros(256,256,3);
for i in range(0,3):
    recon_fft_rgb[:,:,i] = (torch.conj(psf_fft) * torch.fft.fft2(recon_A_gt[:,:,i],s=[fullLength,fullLength] )) / (torch.abs(psf_fft)**2)
    recon_rgb[:,:,i] = crop(torch.fft.fftshift(torch.fft.ifft2(recon_fft_rgb[:,:,i]).real))

recon_rgb = color_range(recon_rgb) # Color Correction 
plt.subplot(122); plt.imshow(recon_rgb); plt.title('Recon'); plt.axis('off');

# %%
from PIL import Image
import glob
import cv2

frame_sz = (256,256)
out = cv2.VideoWriter('transforms.mp4', cv2.VideoWriter_fourcc(*'DIVX'), 60, frame_sz)
for filename in sorted(glob.glob("D:/UCR/Research/Images/GIF_Images/transforms/*.png"), key=os.path.getmtime):
    print(filename)
    img = cv2.imread(filename)
    out.write(img)
out.release()
# fp_in = "D:/UCR/Research/Images/GIF_Images/transforms/image*.png"
# fp_out = "D:/UCR/Research/transforms.gif"

# imgs = [Image.open(f) for f in glob.glob(fp_in)]
# img = imgs[0]
# img.save(fp=fp_out, format='GIF', append_images=imgs, duration=500, save_all=True, loop=1)
# Out:
# D:/UCR/Research/Images/GIF_Images/transforms\image00.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01.png
# D:/UCR/Research/Images/GIF_Images/transforms\image02.png
# D:/UCR/Research/Images/GIF_Images/transforms\image03.png
# D:/UCR/Research/Images/GIF_Images/transforms\image04.png
# D:/UCR/Research/Images/GIF_Images/transforms\image05.png
# D:/UCR/Research/Images/GIF_Images/transforms\image06.png
# D:/UCR/Research/Images/GIF_Images/transforms\image07.png
# D:/UCR/Research/Images/GIF_Images/transforms\image08.png
# D:/UCR/Research/Images/GIF_Images/transforms\image09.png
# D:/UCR/Research/Images/GIF_Images/transforms\image010.png
# D:/UCR/Research/Images/GIF_Images/transforms\image011.png
# D:/UCR/Research/Images/GIF_Images/transforms\image012.png
# D:/UCR/Research/Images/GIF_Images/transforms\image013.png
# D:/UCR/Research/Images/GIF_Images/transforms\image014.png
# D:/UCR/Research/Images/GIF_Images/transforms\image015.png
# D:/UCR/Research/Images/GIF_Images/transforms\image016.png
# D:/UCR/Research/Images/GIF_Images/transforms\image017.png
# D:/UCR/Research/Images/GIF_Images/transforms\image018.png
# D:/UCR/Research/Images/GIF_Images/transforms\image019.png
# D:/UCR/Research/Images/GIF_Images/transforms\image020.png
# D:/UCR/Research/Images/GIF_Images/transforms\image021.png
# D:/UCR/Research/Images/GIF_Images/transforms\image022.png
# D:/UCR/Research/Images/GIF_Images/transforms\image023.png
# D:/UCR/Research/Images/GIF_Images/transforms\image024.png
# D:/UCR/Research/Images/GIF_Images/transforms\image025.png
# D:/UCR/Research/Images/GIF_Images/transforms\image026.png
# D:/UCR/Research/Images/GIF_Images/transforms\image027.png
# D:/UCR/Research/Images/GIF_Images/transforms\image028.png
# D:/UCR/Research/Images/GIF_Images/transforms\image029.png
# D:/UCR/Research/Images/GIF_Images/transforms\image030.png
# D:/UCR/Research/Images/GIF_Images/transforms\image031.png
# D:/UCR/Research/Images/GIF_Images/transforms\image032.png
# D:/UCR/Research/Images/GIF_Images/transforms\image033.png
# D:/UCR/Research/Images/GIF_Images/transforms\image034.png
# D:/UCR/Research/Images/GIF_Images/transforms\image035.png
# D:/UCR/Research/Images/GIF_Images/transforms\image036.png
# D:/UCR/Research/Images/GIF_Images/transforms\image037.png
# D:/UCR/Research/Images/GIF_Images/transforms\image038.png
# D:/UCR/Research/Images/GIF_Images/transforms\image039.png
# D:/UCR/Research/Images/GIF_Images/transforms\image040.png
# D:/UCR/Research/Images/GIF_Images/transforms\image041.png
# D:/UCR/Research/Images/GIF_Images/transforms\image042.png
# D:/UCR/Research/Images/GIF_Images/transforms\image043.png
# D:/UCR/Research/Images/GIF_Images/transforms\image044.png
# D:/UCR/Research/Images/GIF_Images/transforms\image045.png
# D:/UCR/Research/Images/GIF_Images/transforms\image046.png
# D:/UCR/Research/Images/GIF_Images/transforms\image047.png
# D:/UCR/Research/Images/GIF_Images/transforms\image048.png
# D:/UCR/Research/Images/GIF_Images/transforms\image049.png
# D:/UCR/Research/Images/GIF_Images/transforms\image050.png
# D:/UCR/Research/Images/GIF_Images/transforms\image051.png
# D:/UCR/Research/Images/GIF_Images/transforms\image052.png
# D:/UCR/Research/Images/GIF_Images/transforms\image053.png
# D:/UCR/Research/Images/GIF_Images/transforms\image054.png
# D:/UCR/Research/Images/GIF_Images/transforms\image055.png
# D:/UCR/Research/Images/GIF_Images/transforms\image056.png
# D:/UCR/Research/Images/GIF_Images/transforms\image057.png
# D:/UCR/Research/Images/GIF_Images/transforms\image058.png
# D:/UCR/Research/Images/GIF_Images/transforms\image059.png
# D:/UCR/Research/Images/GIF_Images/transforms\image060.png
# D:/UCR/Research/Images/GIF_Images/transforms\image061.png
# D:/UCR/Research/Images/GIF_Images/transforms\image062.png
# D:/UCR/Research/Images/GIF_Images/transforms\image063.png
# D:/UCR/Research/Images/GIF_Images/transforms\image064.png
# D:/UCR/Research/Images/GIF_Images/transforms\image065.png
# D:/UCR/Research/Images/GIF_Images/transforms\image066.png
# D:/UCR/Research/Images/GIF_Images/transforms\image067.png
# D:/UCR/Research/Images/GIF_Images/transforms\image068.png
# D:/UCR/Research/Images/GIF_Images/transforms\image069.png
# D:/UCR/Research/Images/GIF_Images/transforms\image070.png
# D:/UCR/Research/Images/GIF_Images/transforms\image071.png
# D:/UCR/Research/Images/GIF_Images/transforms\image072.png
# D:/UCR/Research/Images/GIF_Images/transforms\image073.png
# D:/UCR/Research/Images/GIF_Images/transforms\image074.png
# D:/UCR/Research/Images/GIF_Images/transforms\image075.png
# D:/UCR/Research/Images/GIF_Images/transforms\image076.png
# D:/UCR/Research/Images/GIF_Images/transforms\image077.png
# D:/UCR/Research/Images/GIF_Images/transforms\image078.png
# D:/UCR/Research/Images/GIF_Images/transforms\image079.png
# D:/UCR/Research/Images/GIF_Images/transforms\image080.png
# D:/UCR/Research/Images/GIF_Images/transforms\image081.png
# D:/UCR/Research/Images/GIF_Images/transforms\image082.png
# D:/UCR/Research/Images/GIF_Images/transforms\image083.png
# D:/UCR/Research/Images/GIF_Images/transforms\image084.png
# D:/UCR/Research/Images/GIF_Images/transforms\image085.png
# D:/UCR/Research/Images/GIF_Images/transforms\image086.png
# D:/UCR/Research/Images/GIF_Images/transforms\image087.png
# D:/UCR/Research/Images/GIF_Images/transforms\image088.png
# D:/UCR/Research/Images/GIF_Images/transforms\image089.png
# D:/UCR/Research/Images/GIF_Images/transforms\image090.png
# D:/UCR/Research/Images/GIF_Images/transforms\image091.png
# D:/UCR/Research/Images/GIF_Images/transforms\image092.png
# D:/UCR/Research/Images/GIF_Images/transforms\image093.png
# D:/UCR/Research/Images/GIF_Images/transforms\image094.png
# D:/UCR/Research/Images/GIF_Images/transforms\image095.png
# D:/UCR/Research/Images/GIF_Images/transforms\image096.png
# D:/UCR/Research/Images/GIF_Images/transforms\image097.png
# D:/UCR/Research/Images/GIF_Images/transforms\image098.png
# D:/UCR/Research/Images/GIF_Images/transforms\image099.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0100.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0101.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0102.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0103.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0104.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0105.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0106.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0107.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0108.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0109.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0110.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0111.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0112.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0113.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0114.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0115.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0116.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0117.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0118.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0119.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0120.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0121.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0122.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0123.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0124.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0125.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0126.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0127.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0128.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0129.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0130.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0131.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0132.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0133.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0134.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0135.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0136.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0137.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0138.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0139.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0140.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0141.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0142.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0143.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0144.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0145.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0146.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0147.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0148.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0149.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0150.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0151.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0152.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0153.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0154.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0155.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0156.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0157.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0158.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0159.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0160.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0161.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0162.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0163.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0164.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0165.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0166.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0167.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0168.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0169.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0170.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0171.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0172.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0173.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0174.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0175.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0176.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0177.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0178.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0179.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0180.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0181.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0182.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0183.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0184.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0185.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0186.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0187.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0188.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0189.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0190.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0191.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0192.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0193.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0194.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0195.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0196.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0197.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0198.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0199.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0200.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0201.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0202.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0203.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0204.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0205.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0206.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0207.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0208.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0209.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0210.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0211.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0212.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0213.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0214.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0215.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0216.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0217.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0218.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0219.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0220.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0221.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0222.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0223.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0224.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0225.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0226.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0227.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0228.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0229.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0230.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0231.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0232.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0233.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0234.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0235.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0236.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0237.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0238.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0239.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0240.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0241.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0242.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0243.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0244.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0245.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0246.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0247.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0248.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0249.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0250.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0251.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0252.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0253.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0254.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0255.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0256.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0257.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0258.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0259.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0260.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0261.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0262.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0263.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0264.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0265.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0266.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0267.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0268.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0269.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0270.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0271.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0272.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0273.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0274.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0275.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0276.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0277.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0278.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0279.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0280.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0281.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0282.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0283.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0284.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0285.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0286.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0287.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0288.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0289.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0290.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0291.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0292.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0293.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0294.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0295.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0296.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0297.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0298.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0299.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0300.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0301.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0302.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0303.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0304.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0305.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0306.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0307.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0308.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0309.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0310.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0311.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0312.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0313.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0314.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0315.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0316.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0317.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0318.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0319.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0320.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0321.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0322.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0323.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0324.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0325.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0326.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0327.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0328.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0329.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0330.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0331.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0332.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0333.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0334.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0335.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0336.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0337.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0338.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0339.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0340.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0341.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0342.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0343.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0344.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0345.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0346.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0347.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0348.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0349.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0350.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0351.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0352.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0353.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0354.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0355.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0356.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0357.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0358.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0359.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0360.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0361.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0362.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0363.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0364.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0365.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0366.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0367.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0368.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0369.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0370.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0371.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0372.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0373.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0374.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0375.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0376.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0377.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0378.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0379.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0380.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0381.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0382.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0383.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0384.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0385.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0386.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0387.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0388.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0389.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0390.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0391.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0392.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0393.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0394.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0395.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0396.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0397.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0398.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0399.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0400.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0401.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0402.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0403.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0404.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0405.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0406.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0407.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0408.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0409.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0410.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0411.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0412.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0413.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0414.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0415.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0416.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0417.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0418.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0419.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0420.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0421.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0422.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0423.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0424.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0425.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0426.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0427.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0428.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0429.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0430.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0431.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0432.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0433.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0434.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0435.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0436.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0437.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0438.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0439.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0440.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0441.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0442.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0443.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0444.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0445.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0446.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0447.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0448.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0449.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0450.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0451.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0452.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0453.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0454.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0455.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0456.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0457.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0458.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0459.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0460.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0461.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0462.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0463.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0464.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0465.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0466.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0467.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0468.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0469.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0470.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0471.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0472.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0473.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0474.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0475.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0476.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0477.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0478.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0479.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0480.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0481.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0482.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0483.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0484.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0485.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0486.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0487.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0488.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0489.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0490.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0491.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0492.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0493.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0494.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0495.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0496.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0497.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0498.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0499.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0500.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0501.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0502.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0503.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0504.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0505.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0506.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0507.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0508.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0509.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0510.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0511.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0512.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0513.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0514.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0515.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0516.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0517.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0518.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0519.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0520.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0521.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0522.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0523.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0524.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0525.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0526.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0527.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0528.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0529.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0530.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0531.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0532.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0533.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0534.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0535.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0536.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0537.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0538.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0539.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0540.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0541.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0542.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0543.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0544.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0545.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0546.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0547.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0548.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0549.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0550.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0551.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0552.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0553.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0554.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0555.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0556.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0557.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0558.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0559.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0560.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0561.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0562.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0563.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0564.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0565.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0566.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0567.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0568.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0569.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0570.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0571.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0572.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0573.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0574.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0575.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0576.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0577.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0578.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0579.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0580.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0581.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0582.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0583.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0584.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0585.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0586.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0587.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0588.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0589.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0590.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0591.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0592.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0593.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0594.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0595.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0596.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0597.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0598.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0599.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0600.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0601.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0602.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0603.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0604.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0605.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0606.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0607.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0608.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0609.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0610.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0611.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0612.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0613.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0614.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0615.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0616.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0617.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0618.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0619.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0620.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0621.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0622.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0623.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0624.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0625.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0626.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0627.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0628.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0629.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0630.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0631.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0632.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0633.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0634.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0635.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0636.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0637.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0638.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0639.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0640.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0641.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0642.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0643.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0644.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0645.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0646.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0647.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0648.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0649.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0650.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0651.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0652.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0653.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0654.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0655.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0656.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0657.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0658.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0659.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0660.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0661.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0662.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0663.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0664.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0665.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0666.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0667.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0668.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0669.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0670.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0671.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0672.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0673.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0674.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0675.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0676.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0677.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0678.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0679.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0680.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0681.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0682.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0683.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0684.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0685.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0686.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0687.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0688.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0689.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0690.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0691.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0692.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0693.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0694.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0695.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0696.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0697.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0698.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0699.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0700.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0701.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0702.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0703.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0704.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0705.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0706.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0707.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0708.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0709.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0710.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0711.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0712.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0713.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0714.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0715.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0716.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0717.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0718.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0719.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0720.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0721.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0722.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0723.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0724.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0725.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0726.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0727.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0728.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0729.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0730.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0731.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0732.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0733.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0734.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0735.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0736.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0737.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0738.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0739.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0740.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0741.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0742.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0743.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0744.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0745.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0746.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0747.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0748.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0749.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0750.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0751.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0752.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0753.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0754.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0755.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0756.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0757.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0758.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0759.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0760.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0761.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0762.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0763.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0764.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0765.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0766.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0767.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0768.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0769.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0770.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0771.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0772.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0773.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0774.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0775.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0776.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0777.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0778.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0779.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0780.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0781.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0782.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0783.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0784.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0785.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0786.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0787.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0788.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0789.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0790.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0791.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0792.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0793.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0794.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0795.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0796.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0797.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0798.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0799.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0800.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0801.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0802.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0803.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0804.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0805.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0806.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0807.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0808.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0809.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0810.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0811.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0812.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0813.png
# D:/UCR/Research/Images/GIF_Images/transforms\image0814.png
# ...
# D:/UCR/Research/Images/GIF_Images/transforms\image01734.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01735.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01736.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01737.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01738.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01739.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01740.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01741.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01742.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01743.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01744.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01745.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01746.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01747.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01748.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01749.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01750.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01751.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01752.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01753.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01754.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01755.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01756.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01757.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01758.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01759.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01760.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01761.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01762.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01763.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01764.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01765.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01766.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01767.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01768.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01769.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01770.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01771.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01772.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01773.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01774.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01775.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01776.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01777.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01778.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01779.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01780.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01781.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01782.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01783.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01784.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01785.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01786.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01787.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01788.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01789.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01790.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01791.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01792.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01793.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01794.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01795.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01796.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01797.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01798.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01799.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01800.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01801.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01802.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01803.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01804.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01805.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01806.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01807.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01808.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01809.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01810.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01811.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01812.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01813.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01814.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01815.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01816.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01817.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01818.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01819.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01820.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01821.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01822.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01823.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01824.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01825.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01826.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01827.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01828.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01829.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01830.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01831.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01832.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01833.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01834.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01835.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01836.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01837.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01838.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01839.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01840.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01841.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01842.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01843.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01844.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01845.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01846.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01847.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01848.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01849.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01850.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01851.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01852.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01853.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01854.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01855.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01856.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01857.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01858.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01859.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01860.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01861.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01862.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01863.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01864.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01865.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01866.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01867.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01868.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01869.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01870.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01871.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01872.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01873.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01874.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01875.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01876.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01877.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01878.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01879.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01880.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01881.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01882.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01883.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01884.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01885.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01886.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01887.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01888.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01889.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01890.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01891.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01892.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01893.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01894.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01895.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01896.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01897.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01898.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01899.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01900.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01901.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01902.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01903.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01904.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01905.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01906.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01907.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01908.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01909.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01910.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01911.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01912.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01913.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01914.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01915.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01916.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01917.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01918.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01919.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01920.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01921.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01922.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01923.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01924.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01925.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01926.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01927.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01928.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01929.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01930.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01931.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01932.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01933.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01934.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01935.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01936.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01937.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01938.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01939.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01940.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01941.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01942.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01943.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01944.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01945.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01946.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01947.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01948.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01949.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01950.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01951.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01952.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01953.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01954.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01955.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01956.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01957.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01958.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01959.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01960.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01961.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01962.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01963.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01964.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01965.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01966.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01967.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01968.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01969.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01970.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01971.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01972.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01973.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01974.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01975.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01976.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01977.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01978.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01979.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01980.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01981.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01982.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01983.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01984.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01985.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01986.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01987.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01988.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01989.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01990.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01991.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01992.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01993.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01994.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01995.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01996.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01997.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01998.png
# D:/UCR/Research/Images/GIF_Images/transforms\image01999.png

# %%
# np.set_printoptions(threshold=np.inf)
# sm = disp_sm
# print(sm.shape)
# plt.imshow(sm[121:632,121:632,:])

# rows, cols = np.nonzero(sm[:,:,0] > 0.0)
# row2, col2 = np.nonzero(sm[:,:,1] > 0.0)
# row3, col3 = np.nonzero(sm[:,:,2] > 0.0)
# nrg = np.zeros((767,767,3))

# # with open('Energy.txt', 'a') as fp:
# #     fp.write(str(sm))

# for r, c in zip(rows, cols):
#     nrg[r][c][0] = 1
# for r, c in zip(row2, col2):
#     nrg[r][c][1] = 1
# for r, c in zip(row3, col3):
#     nrg[r][c][2] = 1
# plt.imshow(nrg[121:632,121:632,:]); plt.colorbar();

# %% [markdown]
# 11 - 4 - 21
# #### TODO
# - ~~PSNR Statistics? - Possible built in functions for this~~ \\
# - ~~Save the first 100 Images (since they show the most dramatic change)~~ \\
# - Make forward model more realistic \\
#   - Different types of sampling patterns \\
#   - Reconstruction Side, **try different initializations for (z). Solve this problem by drawing different values for (z)**
#   - Does quality degrade when going down from lower and lower amounts of measurements
#
#
# Reconstruction Error - Finds an image that matches observation
#
#
# #### Next Steps
#
# How many measurements are needed to recover a single image?
# See what is out there in terms of video generative models, or some other ways to reconstruct video.
#
#
#
# Showing not just a line sensor, but a distributed sensor, see if video works for that.
#
# PULSE
# Demarcus
# ILO
